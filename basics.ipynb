# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/saiasish9849/fact_sales.csv")

df.head()
# Out:
#    sales_id  date_sk  store_sk  product_sk  customer_sk  promotion_sk  \
# 0         1        1         5           2            8           1.0
# 1         2        1         5           7            8           1.0
# 2         3        1         3           8           17           NaN
# 3         4        1         5           8           33           1.0
# 4         5        1         1           4           18           NaN
#
#    quantity  unit_price  gross_amount  discount_amount  net_amount  \
# 0         3        3.10          9.30             0.93        8.37
# 1         4       24.60         98.40             9.84       88.56
# 2         2        7.54         15.08             0.00       15.08
# 3         1        7.57          7.57             0.76        6.81
# 4         4        5.50         22.00             0.00       22.00
#
#    payment_method
# 0  Digital Wallet
# 1            Cash
# 2            Card
# 3            Card
# 4            Cash

# %%
df = df[df['payment_method'] == 'Card']
df.head()
# Out:
#     sales_id  date_sk  store_sk  product_sk  customer_sk  promotion_sk  \
# 2          3        1         3           8           17           NaN
# 3          4        1         5           8           33           1.0
# 6          7        1         1           1           16           NaN
# 9         10        1         4           2           30           1.0
# 12        13        1         3           3           16           1.0
#
#     quantity  unit_price  gross_amount  discount_amount  net_amount  \
# 2          2        7.54         15.08             0.00       15.08
# 3          1        7.57          7.57             0.76        6.81
# 6          1        2.41          2.41             0.00        2.41
# 9          1        3.22          3.22             0.32        2.90
# 12         1        2.95          2.95             0.30        2.65
#
#    payment_method
# 2            Card
# 3            Card
# 6            Card
# 9            Card
# 12           Card

# %%
df.to_csv("filtered_sales.csv", index=False)
